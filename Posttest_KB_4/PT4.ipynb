# %% [markdown]
# ## **Muhammad Daffa Putra Mahardika**
# ## **2009106036**
# ## **Posttest 4**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

df = pd.read_csv("bodyPerformance.csv")

df.head()
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %% [markdown]
# # **Bagi dataset menjadi training set dan testing set dengan proporsi 70:30**

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:,:-1]
y = df.iloc[:,-1] 

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print("Dimensi X_train : ", x_train.shape)
print("Dimensi X_train : ", x_test.shape)
print("Dimensi y_train : ", y_train.shape)
print("Dimensi y_test  : ", y_test.shape)
# Out:
# Dimensi X_train :  (2100, 11)
# Dimensi X_train :  (900, 11)
# Dimensi y_train :  (2100,)
# Dimensi y_test  :  (900,)

# %% [markdown]
# # **Lakukan normalisasi data pada salah satu attribute menggunakan Min Max scaler (buatlah copy dataset terlebih dahulu)**

# %%
from sklearn.preprocessing import MinMaxScaler 

dfAngka= df.select_dtypes(include=['float64','int64'])

dfAngka.head()
# Out:
#     age  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  \
# 0  27.0      172.3      75.24        21.3       80.0     130.0       54.9
# 1  25.0      165.0      55.80        15.7       77.0     126.0       36.4
# 2  31.0      179.6      78.00        20.1       92.0     152.0       44.8
# 3  32.0      174.5      71.10        18.4       76.0     147.0       41.4
# 4  28.0      173.8      67.70        17.1       70.0     127.0       43.5
#
#    sit and bend forward_cm  sit-ups counts  broad jump_cm
# 0                     18.4            60.0          217.0
# 1                     16.3            53.0          229.0
# 2                     12.0            49.0          181.0
# 3                     15.2            53.0          219.0
# 4                     27.1            45.0          217.0

# %%
ss = MinMaxScaler()

Scaled_data = ss.fit_transform(dfAngka)

print("Nilai Data Sebelum scaling : ", dfAngka.head())
print("Nilai standar deviasi: \n", np.std(dfAngka))

print("\n\n Nilai Data setelah scaling : ", Scaled_data)
print("Nilai standar deviasi: ", np.std(dfAngka))
# Out:
# Nilai Data Sebelum scaling :      age  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  \
# 0  27.0      172.3      75.24        21.3       80.0     130.0       54.9
# 1  25.0      165.0      55.80        15.7       77.0     126.0       36.4
# 2  31.0      179.6      78.00        20.1       92.0     152.0       44.8
# 3  32.0      174.5      71.10        18.4       76.0     147.0       41.4
# 4  28.0      173.8      67.70        17.1       70.0     127.0       43.5
#
#    sit and bend forward_cm  sit-ups counts  broad jump_cm
# 0                     18.4            60.0          217.0
# 1                     16.3            53.0          229.0
# 2                     12.0            49.0          181.0
# 3                     15.2            53.0          219.0
# 4                     27.1            45.0          217.0
# Nilai standar deviasi:
#  age                        13.417052
# height_cm                   8.346870
# weight_kg                  12.093821
# ...

# %% [markdown]
# # **Lakukan standarisasi pada dataset (buatlah copy dataset terlebih dahulu)**

# %%
from sklearn.preprocessing import StandardScaler #3

dfAngka2 = df.select_dtypes(include=['float64','int64'])

ss = StandardScaler()
Scaled_data = ss.fit_transform(dfAngka2)

# %%
print("Nilai Data Sebelum scaling : ")
print(dfAngka2)
print("Nilai standar deviasi: \n", np.std(dfAngka2))

print("\n\n Nilai Data setelah scaling : ")
print(Scaled_data)
print("Nilai standar deviasi: ", np.std(Scaled_data))
# Out:
# Nilai Data Sebelum scaling :
#        age  height_cm  weight_kg  body fat_%  diastolic  systolic  gripForce  \
# 0     27.0      172.3      75.24        21.3       80.0     130.0       54.9
# 1     25.0      165.0      55.80        15.7       77.0     126.0       36.4
# 2     31.0      179.6      78.00        20.1       92.0     152.0       44.8
# 3     32.0      174.5      71.10        18.4       76.0     147.0       41.4
# 4     28.0      173.8      67.70        17.1       70.0     127.0       43.5
# ...    ...        ...        ...         ...        ...       ...        ...
# 2995  39.0      170.0      51.50        16.8       55.0     100.0       30.6
# 2996  42.0      163.2      54.30        25.5       73.0     102.0       31.9
# 2997  55.0      158.3      60.90        35.3       77.0     146.0       27.9
# 2998  26.0      164.4      54.60        29.9       72.0     131.0       27.2
# 2999  25.0      163.7      49.80        26.0       80.0     142.0       19.9
#
# ...

# %% [markdown]
# # **Lakukan Data cleaning pada data dengan nilai null (jika tidak ada nilai null pada dataset, maka buatlah menjadi ada). Ganti nilai null sesuai ketentuan. (bilangan bulat : median/modus, bilangan desimal : mean, tulisan : modus)**

# %%
from sklearn.impute import SimpleImputer

df.isna().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
df.dtypes
# Out:
# age                        float64
# gender                      object
# height_cm                  float64
# weight_kg                  float64
# body fat_%                 float64
# diastolic                  float64
# systolic                   float64
# gripForce                  float64
# sit and bend forward_cm    float64
# sit-ups counts             float64
# broad jump_cm              float64
# class                       object
# dtype: object

# %%
# karna saya tidak ada nilai null maka disini saya membuat nilai null terlebih dahulu
imputer = SimpleImputer(strategy='most_frequent' )

df.iloc[1,1] = np.nan

df.isna().sum()
# Out:
# age                        0
# gender                     1
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
df["gender"] = imputer.fit_transform(df[["gender"]])

df.isna().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
imputer2 = SimpleImputer(strategy='mean' )
df["age"] = imputer.fit_transform(df[["age"]])

df.isna().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
imputer3 = SimpleImputer(strategy='median' )

df["weight_kg"] = df["weight_kg"].astype("int64")
print(df["weight_kg"].dtypes)
# Out:
# int64

# %%
df.iloc[3,3] = np.nan

df.isna().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  1
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
df["weight_kg"] = imputer.fit_transform(df[["weight_kg"]])

df.isna().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %% [markdown]
# # **Lakukan Data cleaning pada data dengan nilai duplikat. (Jika tidak ada nilai duplikat pada dataset, maka buatlah menjadi ada)**

# %%
print("Nilai Duplikat: ") 
df[df.duplicated()]
# Out:
# Nilai Duplikat:
# Empty DataFrame
# Columns: [age, gender, height_cm, weight_kg, body fat_%, diastolic, systolic, gripForce, sit and bend forward_cm, sit-ups counts, broad jump_cm, class]
# Index: []

# %%
df = df.append(df.iloc[0:50])

print("Nilai Duplikat: ")
df[df.duplicated()]
# Out:
# Nilai Duplikat:
#      age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0   27.0      M      172.3       75.0        21.3       80.0     130.0
# 1   25.0      M      165.0       55.0        15.7       77.0     126.0
# 2   31.0      M      179.6       78.0        20.1       92.0     152.0
# 3   32.0      M      174.5       71.0        18.4       76.0     147.0
# 4   28.0      M      173.8       67.0        17.1       70.0     127.0
# 5   36.0      F      165.4       55.0        22.0       64.0     119.0
# 6   42.0      F      164.5       63.0        32.2       72.0     135.0
# 7   33.0      M      174.9       77.0        36.9       84.0     137.0
# 8   54.0      M      166.8       67.0        27.6       85.0     165.0
# 9   28.0      M      185.0       84.0        14.4       81.0     156.0
# 10  42.0      M      169.2       65.0        19.3       63.0     110.0
# 11  57.0      F      153.0       49.0        20.9       69.0     106.0
# ...

# %%
df.drop_duplicates(inplace=True)

print("Nilai Duplikat: ")
df[df.duplicated()]
# Out:
# Nilai Duplikat:
# Empty DataFrame
# Columns: [age, gender, height_cm, weight_kg, body fat_%, diastolic, systolic, gripForce, sit and bend forward_cm, sit-ups counts, broad jump_cm, class]
# Index: []

# %% [markdown]
# # **Ganti tipe data salah satu attribute angka**

# %%
df.dtypes
# Out:
# age                        float64
# gender                      object
# height_cm                  float64
# weight_kg                  float64
# body fat_%                 float64
# diastolic                  float64
# systolic                   float64
# gripForce                  float64
# sit and bend forward_cm    float64
# sit-ups counts             float64
# broad jump_cm              float64
# class                       object
# dtype: object

# %%
df["age"].dtypes
print(df["age"].dtypes)

df["age"] = df["age"].astype("int64")
print(df["age"].dtypes)
# Out:
# float64
# int64

# %% [markdown]
# # **Lakukan one hot encoding pada dataset yang kalian miliki.**

# %%
from sklearn.preprocessing import OneHotEncoder # one hot encoding

df.head()
# Out:
#    age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0   27      M      172.3       75.0        21.3       80.0     130.0
# 1   25      M      165.0       55.0        15.7       77.0     126.0
# 2   31      M      179.6       78.0        20.1       92.0     152.0
# 3   32      M      174.5       71.0        18.4       76.0     147.0
# 4   28      M      173.8       67.0        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %%
encoder = OneHotEncoder(sparse=False)
genderEnc = encoder.fit_transform(df[["gender"]])

gender = pd.DataFrame(genderEnc)
df = df.join(gender)
df.head()
# Out:
#    age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0   27      M      172.3       75.0        21.3       80.0     130.0
# 1   25      M      165.0       55.0        15.7       77.0     126.0
# 2   31      M      179.6       78.0        20.1       92.0     152.0
# 3   32      M      174.5       71.0        18.4       76.0     147.0
# 4   28      M      173.8       67.0        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class  \
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B
#
#      0    1
# 0  0.0  1.0
# 1  0.0  1.0
# 2  0.0  1.0
# 3  0.0  1.0
# 4  0.0  1.0

# %%
df = df.rename(columns={
    0 : 'F',
    1 : 'M'
})

df.head()
# Out:
#    age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0   27      M      172.3       75.0        21.3       80.0     130.0
# 1   25      M      165.0       55.0        15.7       77.0     126.0
# 2   31      M      179.6       78.0        20.1       92.0     152.0
# 3   32      M      174.5       71.0        18.4       76.0     147.0
# 4   28      M      173.8       67.0        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class  \
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B
#
#      F    M
# 0  0.0  1.0
# 1  0.0  1.0
# 2  0.0  1.0
# 3  0.0  1.0
# 4  0.0  1.0
